# %% [markdown]
# Introducción

# %% [markdown]
# Objetivos

# %% [markdown]
# El objetivo de este proyecto es establecer cual ha sido el contenido que han tenido disponible los usuarios de  NETFLIX, en este caso se busca encontrar que tipo de contenido hay disponible, entre ellos estan: peliculas ,tvshows, series, entre otros. Esto permitira a la plataforma saber hacia donde se deben demarcar los presuepuestos del respectivo año, para generar mayor contenido de esta indole, y a su vez, permitira evidenciar una categoria,y el tipo de rating asociado.

# %% [markdown]
# Hipotesis
#
# Para determinar el tipo de proyecto que mas realizar durante los proximos años, es necesario conocer que prefieren los usuarios de la plataforma, para ello es de suma necesidad saber

# %% [markdown]
# Librerias

# %%
import pandas as pd

# %% [markdown]
# Vincular

# %%
Peliculas = pd.read_csv("netflix_titles.csv")

# %%
Peliculas.shape
# Out:
# (8807, 12)

# %% [markdown]
# Descripción Dataset:
#
# ShowID: id del show.
# type: tipo (movie/tvshow)
# tittle: Titulo del contenido.
# Director: Director del contenido.
# Cast: Participantes del elenco
# Country: Pais
# date_added: Dia en que se agrego el contenido.
# realse_year: Año de lanzamiento
# rating: Tipo de rating-
# Listed_in: Tipos de categorias a la cual pertenece.
# Descripción: Descripción del contenido
# rating: Tv Rating de la movie/show
# duration: Total de duración en minutos o numero de temporadas

# %%
Peliculas.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# Encontrar  La categoria que posee más titulos en la Plataforma

# %%
categoria_mas_comun = Peliculas['type'].mode()[0]

print("La categoría más común es:", categoria_mas_comun)
# Out:
# La categoría más común es: Movie

# %%
datos_categoria_mas_comun = Peliculas[Peliculas['type'] == categoria_mas_comun]
df=datos_categoria_mas_comun.head(40)
print("Datos con la categoría más común:")
df.head(40)
# Out:
# Datos con la categoría más común:
#    show_id   type                                              title  \
# 0       s1  Movie                               Dick Johnson Is Dead
# 6       s7  Movie                   My Little Pony: A New Generation
# 7       s8  Movie                                            Sankofa
# 9      s10  Movie                                       The Starling
# 12     s13  Movie                                       Je Suis Karl
# 13     s14  Movie                   Confessions of an Invisible Girl
# 16     s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 18     s19  Movie                                          Intrusion
# 22     s23  Movie                                    Avvai Shanmughi
# 23     s24  Movie       Go! Go! Cory Carson: Chrissy Takes the Wheel
# 24     s25  Movie                                              Jeans
# 26     s27  Movie                                     Minsara Kanavu
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_1.groupby('rating').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Se puede apreciar que existe un alza de contenido asociado al rating TV-PG (supervisión de los padres). Esto puede indicar que las peliculas mas vistas son las familiares.

# %%
import pandas as pd


# Suponiendo que la columna de interés se llama 'columna_palabras'
# Calcular la frecuencia de cada palabra en la columna 'columna_palabras'
frecuencias = df['listed_in'].value_counts()

# Obtener la palabra que más se repite
palabra_mas_comun = frecuencias.idxmax()

print("La palabra que más se repite es:", palabra_mas_comun)
# Out:
# La palabra que más se repite es: Action & Adventure, Anime Features, International Movies

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_1.groupby('listed_in').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
Tiempo = df['duration'].mode()[0]

print("El tiempo medio es:", Tiempo)
# Out:
# El tiempo medio es: 91 min

# %% [markdown]
# **Resolución en base a los análisis:** Los recursos de la organización deben estar orientados a la creación de peliculas, las cuales deben estar dentro de las siguientes categorias: acción, aventura , anime o internacional. Con un tiempo de duración de 91 min y el contenido debe estar asociado a  rating TV-PG (supervisión de los padres).
